# %% [markdown]
# #### Python Code for Local DeepSeek Chat versions via LM Studio

# %% [markdown]
# ##### Source code: https://github.com/Farama-Foundation/Gymnasium/blob/main/gymnasium/envs/classic_control/cartpole.py

# %% [markdown]
# ##### Import libraries

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import requests
import time
import pygame
import re
import json

# %% [markdown]
# ##### LLM-Based Agent  DeepSeek Chat (Prompt Engineering)

# %%
class LMStudio_Agent:
    def __init__(self, env_name):
        self.env_name = env_name
        self.api_url = "http://localhost:1234/v1/completions"  # LM Studio API Endpoint

    def select_action(self, state):
        # Shorter prompt
        prompt = f"""
        Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {state[0]:.3f}
        Cart Velocity: {state[1]:.3f}
        Pole Angle: {state[2]:.3f}
        Pole Angular Velocity: {state[3]:.3f}

        Select the best action:
        (0) Move LEFT
        (1) Move RIGHT

        ONLY reply with `0` or `1` on a new line.
        DO NOT leave the response blank.
        DO NOT include explanations.
        """

        print("Sending Prompt:", prompt)  # Debugging

        headers = {"Content-Type": "application/json"}
        data = {
            "model": "deepseek-llm-7B-chat-GGUF",  # Ensure it's an instruction-tuned model
            "prompt": prompt,
            "max_tokens": 5,  # Ensures a short response
            "temperature": 0.7,  # Make the model more willing to respond
            "top_p": 0.9,  # Increase sampling variety
            "stop": ["\n"]  # Prevents unnecessary text generation
        }


        try:
            response = requests.post(self.api_url, headers=headers, json=data)

            # Check if API call was successful
            if response.status_code != 200:
                print(f"API Error: {response.status_code} - {response.text}")
                return 0  # Default action on failure
            
            response_json = response.json()
            print("API Response:", response_json)  # Debug response

            # Extract action using regex
            match = re.search(r'\b[01]\b', response_json.get("choices", [{}])[0].get("text", ""))
            action = int(match.group(0)) if match else 0

            print(f"Selected Action: {action}")  # Debug action
            return action

        except Exception as e:
            print(f"Error communicating with LM Studio: {e}")
            return 0  # Default safe action

# %% [markdown]
# ##### Run Experiment

# %%
def run_experiment():
    env = gym.make("CartPole-v1")
    llm_agent = LMStudio_Agent("CartPole-v1")

    episodes = 10
    llm_scores = []

    print("\nRunning LLM Agent...")
    for episode in range(episodes):
        state, _ = env.reset()
        total_reward = 0
        done = False
        while not done:
            action = llm_agent.select_action(state)
            print(f"Action: {action}")
            next_state, reward, done, _, _ = env.step(action)
            state = next_state
            total_reward += reward
            time.sleep(0.1)
        llm_scores.append(total_reward)
        print(f"LLM Episode {episode + 1}: Score = {total_reward}")

    env.close()

# %%
if __name__ == "__main__":
    run_experiment()
# Out:
# Running LLM Agent...
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.043
#         Cart Velocity: -0.008
#         Pole Angle: -0.037
#         Pole Angular Velocity: 0.042
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-2v6afhgicjnkme0o2xj0oq', 'object': 'text_completion', 'created': 1741178158, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.044
#         Cart Velocity: -0.203
#         Pole Angle: -0.036
#         Pole Angular Velocity: 0.322
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-trvyobqntbgjjrrt0mk78', 'object': 'text_completion', 'created': 1741178165, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.048
#         Cart Velocity: -0.397
#         Pole Angle: -0.030
#         Pole Angular Velocity: 0.603
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-0ptxaa5bhe9b5y7re990ti', 'object': 'text_completion', 'created': 1741178170, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.056
#         Cart Velocity: -0.592
#         Pole Angle: -0.018
#         Pole Angular Velocity: 0.886
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-t6vnobz5raqlrqvx9wtos', 'object': 'text_completion', 'created': 1741178175, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.067
#         Cart Velocity: -0.787
#         Pole Angle: -0.000
#         Pole Angular Velocity: 1.173
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-su0z7nmx6yjsi9sucezto', 'object': 'text_completion', 'created': 1741178181, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.083
#         Cart Velocity: -0.982
#         Pole Angle: 0.023
#         Pole Angular Velocity: 1.466
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-blr8v16ss1rengr5irmra9', 'object': 'text_completion', 'created': 1741178186, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.103
#         Cart Velocity: -1.178
#         Pole Angle: 0.053
#         Pole Angular Velocity: 1.766
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-akmxvkjsh8s66n8gck4svq', 'object': 'text_completion', 'created': 1741178191, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.126
#         Cart Velocity: -1.373
#         Pole Angle: 0.088
#         Pole Angular Velocity: 2.074
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-l1rqn9t4wd6jmzjwcajmp', 'object': 'text_completion', 'created': 1741178196, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.154
#         Cart Velocity: -1.569
#         Pole Angle: 0.129
#         Pole Angular Velocity: 2.393
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-yxxleqfrnnk4mxs7la5nqe', 'object': 'text_completion', 'created': 1741178202, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.185
#         Cart Velocity: -1.765
#         Pole Angle: 0.177
#         Pole Angular Velocity: 2.722
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-rncdjlc3g6v6y2aciy4ns', 'object': 'text_completion', 'created': 1741178207, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# LLM Episode 1: Score = 10.0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.021
#         Cart Velocity: 0.015
#         Pole Angle: -0.020
#         Pole Angular Velocity: 0.014
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-zzl7za9id3dftx3bxwdzd', 'object': 'text_completion', 'created': 1741178213, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.020
#         Cart Velocity: -0.180
#         Pole Angle: -0.019
#         Pole Angular Velocity: 0.300
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-mcyvgi7wo1k3u4gagm7o0q', 'object': 'text_completion', 'created': 1741178218, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.024
#         Cart Velocity: -0.375
#         Pole Angle: -0.013
#         Pole Angular Velocity: 0.587
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-uzkzqxvvzeswjqhl1v31gf', 'object': 'text_completion', 'created': 1741178224, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.032
#         Cart Velocity: -0.570
#         Pole Angle: -0.002
#         Pole Angular Velocity: 0.875
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-981ygw39ixbxbdttxuuur', 'object': 'text_completion', 'created': 1741178229, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 135, 'completion_tokens': 0, 'total_tokens': 135}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.043
#         Cart Velocity: -0.765
#         Pole Angle: 0.016
#         Pole Angular Velocity: 1.167
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-cyz6zdv3gacqdlluknn79', 'object': 'text_completion', 'created': 1741178235, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.058
#         Cart Velocity: -0.960
#         Pole Angle: 0.039
#         Pole Angular Velocity: 1.465
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-62gtdi8gw4ck2k9sg8a7gb', 'object': 'text_completion', 'created': 1741178240, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.077
#         Cart Velocity: -1.156
#         Pole Angle: 0.068
#         Pole Angular Velocity: 1.770
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-7ynkxn32drom59c0dgrc5c', 'object': 'text_completion', 'created': 1741178246, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.101
#         Cart Velocity: -1.351
#         Pole Angle: 0.104
#         Pole Angular Velocity: 2.083
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-3g5i0x7ladt15y587h433m', 'object': 'text_completion', 'created': 1741178251, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.128
#         Cart Velocity: -1.547
#         Pole Angle: 0.145
#         Pole Angular Velocity: 2.406
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-e12bygsxyjm0epssl5nwu4g', 'object': 'text_completion', 'created': 1741178256, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.159
#         Cart Velocity: -1.744
#         Pole Angle: 0.194
#         Pole Angular Velocity: 2.739
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
#
# API Response: {'id': 'cmpl-h0m9p8cqq7wlqir0brppu', 'object': 'text_completion', 'created': 1741178262, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'text': '', 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 134, 'completion_tokens': 0, 'total_tokens': 134}}
# Selected Action: 0
# Action: 0
# LLM Episode 2: Score = 10.0
# Sending Prompt:
#         Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.014
#         Cart Velocity: -0.020
#         Pole Angle: 0.043
#         Pole Angular Velocity: -0.011
#
#         Select the best action:
#         (0) Move LEFT
#         (1) Move RIGHT
#
#         ONLY reply with `0` or `1` on a new line.
#         DO NOT leave the response blank.
#         DO NOT include explanations.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 if __name__ == "__main__":
# ----> 2     run_experiment()
#
# Cell In[25], line 14, in run_experiment()
#      12 done = False
#      13 while not done:
# ---> 14     action = llm_agent.select_action(state)
#      15     print(f"Action: {action}")
#      16     next_state, reward, done, _, _ = env.step(action)
#
# Cell In[24], line 40, in LMStudio_Agent.select_action(self, state)
#      29 data = {
#      30     "model": "deepseek-llm-7B-chat-GGUF",  # Ensure it's an instruction-tuned model
#      31     "prompt": prompt,
#    (...)
#      35     "stop": ["\n"]  # Prevents unnecessary text generation
#      36 }
#      39 try:
# ---> 40     response = requests.post(self.api_url, headers=headers, json=data)
#      42     # Check if API call was successful
#      43     if response.status_code != 200:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# #### Second code attempt from ChatGPT

# %% [markdown]
# ##### Import libraries

# %%
import gymnasium as gym
import requests
import json
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ##### LLM API details

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "deepseek-llm-7B-chat-GGUF"  # Adjust if needed

# %% [markdown]
# ##### Definition of query for LLM

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    You are controlling a CartPole in OpenAI Gymnasium.
    The current state: [cart_position, cart_velocity, pole_angle, pole_velocity].
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
    try:
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        raw_result = response_json["choices"][0]["message"]["content"].strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        print(f"Final Action: {action}")
    except Exception as e:
        print("Error processing LLM response:", e)
        action = 0  # Default action in case of failure

    return action

# %% [markdown]
# #### Running carpole

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
# LLM Response: {'id': 'chatcmpl-c3vmyqdkyqg1ootj2tcphn', 'object': 'chat.completion', 'created': 1741181876, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 1, 'total_tokens': 139}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# LLM Response: {'id': 'chatcmpl-j3bdkm94u8pp8n45ztlhk', 'object': 'chat.completion', 'created': 1741181883, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'The observation provided is for the CartPole'}}], 'usage': {'prompt_tokens': 137, 'completion_tokens': 9, 'total_tokens': 146}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: The observation provided is for the CartPole
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-oc619q1kkuc256207wiil1', 'object': 'chat.completion', 'created': 1741181893, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 1, 'total_tokens': 139}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# LLM Response: {'id': 'chatcmpl-83zbo4hpgp387qgmlyq2yw', 'object': 'chat.completion', 'created': 1741181900, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'To determine the appropriate action for this CartP'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 9, 'total_tokens': 147}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: To determine the appropriate action for this CartP
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-2sqmtarzxscqs4euaw03n8', 'object': 'chat.completion', 'created': 1741181908, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '```python'}}], 'usage': {'prompt_tokens': 136, 'completion_tokens': 2, 'total_tokens': 138}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: ```python
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-vfn4xyvvkwpigsqeqr6dw', 'object': 'chat.completion', 'created': 1741181916, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': '[0, 0, 0,'}}], 'usage': {'prompt_tokens': 136, 'completion_tokens': 9, 'total_tokens': 145}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: [0, 0, 0,
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-igpi95g3irqffqeprryvuw', 'object': 'chat.completion', 'created': 1741181925, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'Please provide the current state of the CartP'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 9, 'total_tokens': 147}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: Please provide the current state of the CartP
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-u09ywqoj8wg11rapln82ucf', 'object': 'chat.completion', 'created': 1741181933, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 1, 'total_tokens': 139}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# LLM Response: {'id': 'chatcmpl-2ic77iu3r6szjt22mdfob', 'object': 'chat.completion', 'created': 1741181940, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'Part #1: Understanding the state of Cart'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 9, 'total_tokens': 147}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: Part #1: Understanding the state of Cart
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-y0986yuaqarw0fohudo8ir', 'object': 'chat.completion', 'created': 1741181949, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 137, 'completion_tokens': 1, 'total_tokens': 138}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# LLM Response: {'id': 'chatcmpl-vt2sphetfqnkd7uupenbk', 'object': 'chat.completion', 'created': 1741181956, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "(Note: The agent should respond with '"}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 9, 'total_tokens': 147}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: (Note: The agent should respond with '
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-ficbkbn5fflwu5a901nn0f', 'object': 'chat.completion', 'created': 1741181965, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'To solve this problem, I will compare the'}}], 'usage': {'prompt_tokens': 137, 'completion_tokens': 9, 'total_tokens': 146}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: To solve this problem, I will compare the
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-4cqoyh174vsgp75tr02859', 'object': 'chat.completion', 'created': 1741181973, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 137, 'completion_tokens': 1, 'total_tokens': 138}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-0zh8yd7xun491919t5uboj6', 'object': 'chat.completion', 'created': 1741181980, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 138, 'completion_tokens': 1, 'total_tokens': 139}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-91drfhstjygp27bgdvjk8j', 'object': 'chat.completion', 'created': 1741181988, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'Part #1: Identifying the current state'}}], 'usage': {'prompt_tokens': 136, 'completion_tokens': 9, 'total_tokens': 145}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: Part #1: Identifying the current state
# Final Action: 0
# LLM Response: {'id': 'chatcmpl-s1eb83dir5io2di6lqjm9', 'object': 'chat.completion', 'created': 1741181997, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 137, 'completion_tokens': 1, 'total_tokens': 138}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# LLM Response: {'id': 'chatcmpl-b9xzm9nf42qfd0ziipyd1u', 'object': 'chat.completion', 'created': 1741182004, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'To solve this problem, you can follow these'}}], 'usage': {'prompt_tokens': 136, 'completion_tokens': 9, 'total_tokens': 145}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: To solve this problem, you can follow these
# Final Action: 0
# Total reward: 17.0

# %% [markdown]
# ##### Change in Prompt -- details of the observation

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f}
        Cart Velocity: {observation[1]:.3f}
        Pole Angle: {observation[2]:.3f}
        Pole Angular Velocity: {observation[3]:.3f}
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        raw_result = response_json["choices"][0]["message"]["content"].strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        print(f"Final Action: {action}")
    except Exception as e:
        print("Error processing LLM response:", e)
        action = 0  # Default action in case of failure

    return action

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.024
#         Cart Velocity: 0.037
#         Pole Angle: -0.044
#         Pole Angular Velocity: 0.002
#
#     Observation: [ 0.0243403   0.03736877 -0.0442324   0.00231141]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-o38lvf5pwsk5h9kcwsonr', 'object': 'chat.completion', 'created': 1741204879, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 172, 'completion_tokens': 1, 'total_tokens': 173}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.025
#         Cart Velocity: -0.157
#         Pole Angle: -0.044
#         Pole Angular Velocity: 0.281
#
#     Observation: [ 0.02508767 -0.15709183 -0.04418617  0.28071693]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-3rys6kp7vzrqem7fij49an', 'object': 'chat.completion', 'created': 1741204888, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.022
#         Cart Velocity: -0.352
#         Pole Angle: -0.039
#         Pole Angular Velocity: 0.559
#
#     Observation: [ 0.02194584 -0.35155654 -0.03857183  0.55914277]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-7mzn4z4lng6umoz3as96bg', 'object': 'chat.completion', 'created': 1741204897, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.015
#         Cart Velocity: -0.156
#         Pole Angle: -0.027
#         Pole Angular Velocity: 0.255
#
#     Observation: [ 0.01491471 -0.15591502 -0.02738898  0.25456145]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-rpvebde94fqr5blmczhgu', 'object': 'chat.completion', 'created': 1741204905, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.012
#         Cart Velocity: 0.040
#         Pole Angle: -0.022
#         Pole Angular Velocity: -0.047
#
#     Observation: [ 0.01179641  0.03958708 -0.02229775 -0.04663305]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-5gf05teatjp25v33k112ly', 'object': 'chat.completion', 'created': 1741204914, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.013
#         Cart Velocity: 0.235
#         Pole Angle: -0.023
#         Pole Angular Velocity: -0.346
#
#     Observation: [ 0.01258815  0.23502155 -0.02323041 -0.34626687]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-bdn73ikagvpnxxrt9jfyhm', 'object': 'chat.completion', 'created': 1741204923, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.017
#         Cart Velocity: 0.040
#         Pole Angle: -0.030
#         Pole Angular Velocity: -0.061
#
#     Observation: [ 0.01728858  0.04023761 -0.03015574 -0.06099893]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-2i0q470jpen1xru0ithilr', 'object': 'chat.completion', 'created': 1741204932, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.018
#         Cart Velocity: 0.236
#         Pole Angle: -0.031
#         Pole Angular Velocity: -0.363
#
#     Observation: [ 0.01809333  0.23577866 -0.03137572 -0.36304158]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-moouu5jya1np5qdb18sgn', 'object': 'chat.completion', 'created': 1741204941, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.023
#         Cart Velocity: 0.041
#         Pole Angle: -0.039
#         Pole Angular Velocity: -0.080
#
#     Observation: [ 0.0228089   0.04111637 -0.03863655 -0.08041482]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-wmqrdtdl8pjeuru21s0gw', 'object': 'chat.completion', 'created': 1741204950, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.024
#         Cart Velocity: -0.153
#         Pole Angle: -0.040
#         Pole Angular Velocity: 0.200
#
#     Observation: [ 0.02363123 -0.15343103 -0.04024485  0.19983217]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-ur992pkd1eewj12jhrdxz', 'object': 'chat.completion', 'created': 1741204958, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.021
#         Cart Velocity: 0.042
#         Pole Angle: -0.036
#         Pole Angular Velocity: -0.105
#
#     Observation: [ 0.02056261  0.04224272 -0.03624821 -0.10526959]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-uno2rpms7aghun3pp22wdm', 'object': 'chat.completion', 'created': 1741204967, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.021
#         Cart Velocity: 0.238
#         Pole Angle: -0.038
#         Pole Angular Velocity: -0.409
#
#     Observation: [ 0.02140746  0.23786488 -0.0383536  -0.4091647 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-67bdrk6w5ce9ghbgk2wos', 'object': 'chat.completion', 'created': 1741204975, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.026
#         Cart Velocity: 0.043
#         Pole Angle: -0.047
#         Pole Angular Velocity: -0.129
#
#     Observation: [ 0.02616476  0.0433071  -0.0465369  -0.12881586]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-mjh4ecu8ijchx94q05kslf', 'object': 'chat.completion', 'created': 1741204984, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.027
#         Cart Velocity: -0.151
#         Pole Angle: -0.049
#         Pole Angular Velocity: 0.149
#
#     Observation: [ 0.0270309  -0.15111837 -0.04911321  0.1488297 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-xtazth9rtvr789ed89shlo', 'object': 'chat.completion', 'created': 1741204993, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.024
#         Cart Velocity: 0.045
#         Pole Angle: -0.046
#         Pole Angular Velocity: -0.159
#
#     Observation: [ 0.02400854  0.04467122 -0.04613662 -0.15893403]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-f8z2qek2tvgf8s32clzmoo', 'object': 'chat.completion', 'created': 1741205002, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.025
#         Cart Velocity: -0.150
#         Pole Angle: -0.049
#         Pole Angular Velocity: 0.119
#
#     Observation: [ 0.02490196 -0.14976089 -0.0493153   0.11884442]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-sdyzp30d4hy21x573ye9', 'object': 'chat.completion', 'created': 1741205011, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.022
#         Cart Velocity: -0.344
#         Pole Angle: -0.047
#         Pole Angular Velocity: 0.396
#
#     Observation: [ 0.02190674 -0.34414285 -0.04693841  0.39557007]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-avgbly11b8uaf5b5i9xy0o', 'object': 'chat.completion', 'created': 1741205019, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.015
#         Cart Velocity: -0.539
#         Pole Angle: -0.039
#         Pole Angular Velocity: 0.673
#
#     Observation: [ 0.01502389 -0.53856844 -0.03902701  0.6730924 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-kla015wf09ohqs9x0af7ij', 'object': 'chat.completion', 'created': 1741205028, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.004
#         Cart Velocity: -0.343
#         Pole Angle: -0.026
#         Pole Angular Velocity: 0.368
#
#     Observation: [ 0.00425252 -0.3429264  -0.02556516  0.3683818 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-e5czkk2q6c9pj6m3t9s94', 'object': 'chat.completion', 'created': 1741205036, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.003
#         Cart Velocity: -0.147
#         Pole Angle: -0.018
#         Pole Angular Velocity: 0.068
#
#     Observation: [-0.00260601 -0.14745072 -0.01819752  0.06774873]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-kocdujts7eff703l9j9m9', 'object': 'chat.completion', 'created': 1741205045, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.006
#         Cart Velocity: -0.342
#         Pole Angle: -0.017
#         Pole Angular Velocity: 0.355
#
#     Observation: [-0.00555503 -0.3423071  -0.01684255  0.35463515]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-zyantwcrxiklua3jebgo69', 'object': 'chat.completion', 'created': 1741205054, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.012
#         Cart Velocity: -0.147
#         Pole Angle: -0.010
#         Pole Angular Velocity: 0.057
#
#     Observation: [-0.01240117 -0.14694977 -0.00974985  0.05668923]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-wbifd0lntarczgz5szzn1c', 'object': 'chat.completion', 'created': 1741205062, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.015
#         Cart Velocity: 0.048
#         Pole Angle: -0.009
#         Pole Angular Velocity: -0.239
#
#     Observation: [-0.01534016  0.04831061 -0.00861606 -0.23905383]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-e3lzh0glkrr4kbts4q2ykf', 'object': 'chat.completion', 'created': 1741205071, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.014
#         Cart Velocity: -0.147
#         Pole Angle: -0.013
#         Pole Angular Velocity: 0.051
#
#     Observation: [-0.01437395 -0.1466872  -0.01339714  0.05089894]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-69cdeu7kglx4ywe3aepfuj', 'object': 'chat.completion', 'created': 1741205079, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.017
#         Cart Velocity: 0.049
#         Pole Angle: -0.012
#         Pole Angular Velocity: -0.246
#
#     Observation: [-0.0173077   0.04862427 -0.01237916 -0.2459806 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-dnev6x8qg044ji46640p9h', 'object': 'chat.completion', 'created': 1741205088, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.016
#         Cart Velocity: -0.146
#         Pole Angle: -0.017
#         Pole Angular Velocity: 0.043
#
#     Observation: [-0.01633521 -0.14631872 -0.01729877  0.04277207]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-oazi7o5mwrb9t76q0qr1', 'object': 'chat.completion', 'created': 1741205096, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.019
#         Cart Velocity: 0.049
#         Pole Angle: -0.016
#         Pole Angular Velocity: -0.255
#
#     Observation: [-0.01926158  0.04904697 -0.01644333 -0.2553182 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-3dywm70zzrd6ef9a4vwql', 'object': 'chat.completion', 'created': 1741205105, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.018
#         Cart Velocity: -0.146
#         Pole Angle: -0.022
#         Pole Angular Velocity: 0.032
#
#     Observation: [-0.01828064 -0.1458364  -0.02154969  0.03213321]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-bh5npt23jypdtoi0kq9j1', 'object': 'chat.completion', 'created': 1741205113, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.021
#         Cart Velocity: -0.341
#         Pole Angle: -0.021
#         Pole Angular Velocity: 0.318
#
#     Observation: [-0.02119737 -0.34064278 -0.02090703  0.31793985]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-mz0uqfalxbewr1fdlihq', 'object': 'chat.completion', 'created': 1741205122, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 175, 'completion_tokens': 1, 'total_tokens': 176}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.028
#         Cart Velocity: -0.535
#         Pole Angle: -0.015
#         Pole Angular Velocity: 0.604
#
#     Observation: [-0.02801023 -0.5354608  -0.01454823  0.6039568 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-dfnjtm8h6pvlfgtpds9vn', 'object': 'chat.completion', 'created': 1741205131, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.039
#         Cart Velocity: -0.340
#         Pole Angle: -0.002
#         Pole Angular Velocity: 0.307
#
#     Observation: [-0.03871945 -0.34013847 -0.0024691   0.30672723]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-49k6ue73bvclsamhlt29vg', 'object': 'chat.completion', 'created': 1741205139, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.046
#         Cart Velocity: -0.535
#         Pole Angle: 0.004
#         Pole Angular Velocity: 0.599
#
#     Observation: [-0.04552221 -0.53522515  0.00366545  0.5986304 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-smh9ly4uio79b6jcbu67v', 'object': 'chat.completion', 'created': 1741205148, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.056
#         Cart Velocity: -0.730
#         Pole Angle: 0.016
#         Pole Angular Velocity: 0.892
#
#     Observation: [-0.05622672 -0.7303982   0.01563806  0.8924657 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-8goom789eb338itb4cx86u', 'object': 'chat.completion', 'created': 1741205157, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.071
#         Cart Velocity: -0.926
#         Pole Angle: 0.033
#         Pole Angular Velocity: 1.190
#
#     Observation: [-0.07083468 -0.92572874  0.03348737  1.1900231 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-imk39hibqph33ca5ucn9', 'object': 'chat.completion', 'created': 1741205166, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.089
#         Cart Velocity: -0.731
#         Pole Angle: 0.057
#         Pole Angular Velocity: 0.908
#
#     Observation: [-0.08934925 -0.7310564   0.05728783  0.90802175]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-7tq1ywim212p5ilbc5gr4r', 'object': 'chat.completion', 'created': 1741205175, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.104
#         Cart Velocity: -0.927
#         Pole Angle: 0.075
#         Pole Angular Velocity: 1.218
#
#     Observation: [-0.10397038 -0.9269051   0.07544827  1.2181463 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-yr5dtdxl9qaqqwbvw5nri', 'object': 'chat.completion', 'created': 1741205183, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.123
#         Cart Velocity: -0.733
#         Pole Angle: 0.100
#         Pole Angular Velocity: 0.950
#
#     Observation: [-0.12250848 -0.7328326   0.09981119  0.9500265 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-pxi4k2gfioln57604n5t8', 'object': 'chat.completion', 'created': 1741205192, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.137
#         Cart Velocity: -0.539
#         Pole Angle: 0.119
#         Pole Angular Velocity: 0.690
#
#     Observation: [-0.13716514 -0.5391856   0.11881172  0.69029737]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-lr77ffgd4ean15hxgxymh', 'object': 'chat.completion', 'created': 1741205201, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.148
#         Cart Velocity: -0.736
#         Pole Angle: 0.133
#         Pole Angular Velocity: 1.018
#
#     Observation: [-0.14794885 -0.73573834  0.13261767  1.0178965 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-iefzqgio147c5avfqsbms', 'object': 'chat.completion', 'created': 1741205209, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 174, 'completion_tokens': 1, 'total_tokens': 175}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.163
#         Cart Velocity: -0.932
#         Pole Angle: 0.153
#         Pole Angular Velocity: 1.349
#
#     Observation: [-0.16266361 -0.93235475  0.1529756   1.3491069 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-5aznauh2rldgvizcz7r95k', 'object': 'chat.completion', 'created': 1741205218, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.181
#         Cart Velocity: -1.129
#         Pole Angle: 0.180
#         Pole Angular Velocity: 1.685
#
#     Observation: [-0.18131071 -1.1290318   0.17995773  1.6854769 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-ryxmop7koxpwpraatjm9b', 'object': 'chat.completion', 'created': 1741205226, 'model': 'deepseek-llm-7b-chat', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 173, 'completion_tokens': 1, 'total_tokens': 174}, 'system_fingerprint': 'deepseek-llm-7b-chat'}
# Raw LLM Response: 1
# Final Action: 1
# Total reward: 41.0

# %% [markdown]
# #### LLM-Agent DeepSeek Coder

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "DeepSeek-Coder-V2-Lite-Instruct-GGUF"  # Adjust if needed
# MODEL_NAME = "deepseek-llm-7B-chat-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.049 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.005 # Min=-Inf and Max=Inf
#         Pole Angle: -0.009 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.043 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04863442 -0.00488335 -0.00856156  0.04293367]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-rnfk9z0w8s3o3q0rqx7v5', 'object': 'chat.completion', 'created': 1741257763, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 223, 'completion_tokens': 2, 'total_tokens': 225}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.049 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.190 # Min=-Inf and Max=Inf
#         Pole Angle: -0.008 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.252 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04853676  0.19036031 -0.00770289 -0.25243816]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-kngie6zizsigil5bnb3ezb', 'object': 'chat.completion', 'created': 1741257769, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 223, 'completion_tokens': 2, 'total_tokens': 225}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.052 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.386 # Min=-Inf and Max=Inf
#         Pole Angle: -0.013 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.548 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.05234396  0.38559142 -0.01275165 -0.5475407 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-5bkqs8iy096ycqaoy011fp', 'object': 'chat.completion', 'created': 1741257774, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 222, 'completion_tokens': 2, 'total_tokens': 224}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.060 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.581 # Min=-Inf and Max=Inf
#         Pole Angle: -0.024 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.844 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.06005579  0.5808902  -0.02370247 -0.84421396]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-xmuqse3xj1ya055rw629p', 'object': 'chat.completion', 'created': 1741257778, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 223, 'completion_tokens': 2, 'total_tokens': 225}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.072 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.776 # Min=-Inf and Max=Inf
#         Pole Angle: -0.041 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.144 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.07167359  0.7763274  -0.04058675 -1.1442553 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-bw991vefh5e5baqq7w2plg', 'object': 'chat.completion', 'created': 1741257783, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 222, 'completion_tokens': 2, 'total_tokens': 224}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.087 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.972 # Min=-Inf and Max=Inf
#         Pole Angle: -0.063 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.449 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.08720014  0.9719554  -0.06347185 -1.4493849 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-tkhubwu0hl53bqc64bm3v', 'object': 'chat.completion', 'created': 1741257787, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 222, 'completion_tokens': 2, 'total_tokens': 224}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.107 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.168 # Min=-Inf and Max=Inf
#         Pole Angle: -0.092 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.761 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.10663925  1.1677976  -0.09245955 -1.7612047 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-eu4mh4hlx4h5pmr222f4aw', 'object': 'chat.completion', 'created': 1741257792, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 222, 'completion_tokens': 2, 'total_tokens': 224}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.130 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.364 # Min=-Inf and Max=Inf
#         Pole Angle: -0.128 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -2.081 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.1299952   1.3638363  -0.12768365 -2.0811512 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-r5htxkrsxbss8si3kthnbb', 'object': 'chat.completion', 'created': 1741257796, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 221, 'completion_tokens': 2, 'total_tokens': 223}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.157 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.560 # Min=-Inf and Max=Inf
#         Pole Angle: -0.169 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -2.410 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.15727192  1.5599988  -0.16930667 -2.4104366 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-zue5eaujm27a7w3iwtfbl', 'object': 'chat.completion', 'created': 1741257801, 'model': 'deepseek-coder-v2-lite-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ' 1'}}], 'usage': {'prompt_tokens': 222, 'completion_tokens': 2, 'total_tokens': 224}, 'system_fingerprint': 'deepseek-coder-v2-lite-instruct'}
# Raw LLM Response: 1
# Final Action: 1
# Total reward: 9.0

# %% [markdown]
# #### LLM-Agent Vicuna

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "vicuna-13B-v1.5-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.049 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.018 # Min=-Inf and Max=Inf
#         Pole Angle: -0.000 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.041 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04862015 -0.01751299 -0.00034378 -0.04132786]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-scr242x4nps2d6yccrxukp', 'object': 'chat.completion', 'created': 1741258139, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 239, 'completion_tokens': 0, 'total_tokens': 239}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.048 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.213 # Min=-Inf and Max=Inf
#         Pole Angle: -0.001 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.251 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04826989 -0.21263    -0.00117033  0.25124657]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-0nv1nj1i87kmztr99abfqi', 'object': 'chat.completion', 'created': 1741258183, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 237, 'completion_tokens': 0, 'total_tokens': 237}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.044 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.408 # Min=-Inf and Max=Inf
#         Pole Angle: 0.004 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.544 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04401729 -0.40773523  0.0038546   0.54356015]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-cojpo9bckdl9qyjl0q9veh', 'object': 'chat.completion', 'created': 1741258217, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 238, 'completion_tokens': 0, 'total_tokens': 238}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.036 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.603 # Min=-Inf and Max=Inf
#         Pole Angle: 0.015 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.837 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03586259 -0.6029111   0.0147258   0.8374551 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-35gafz7t46qoef1t2onr8i', 'object': 'chat.completion', 'created': 1741258250, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 236, 'completion_tokens': 0, 'total_tokens': 236}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.024 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.798 # Min=-Inf and Max=Inf
#         Pole Angle: 0.031 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.135 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.02380437 -0.79823107  0.0314749   1.1347325 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-ub4of4q3seg0oroayg4noi', 'object': 'chat.completion', 'created': 1741258281, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 237, 'completion_tokens': 0, 'total_tokens': 237}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.008 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.994 # Min=-Inf and Max=Inf
#         Pole Angle: 0.054 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.437 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00783974 -0.9937504   0.05416955  1.4371183 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-d776bnoag0lvikcyyv829p', 'object': 'chat.completion', 'created': 1741258315, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 237, 'completion_tokens': 0, 'total_tokens': 237}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.012 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.189 # Min=-Inf and Max=Inf
#         Pole Angle: 0.083 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.746 # Min=-Inf and Max=Inf
#
#     Observation: [-0.01203526 -1.1894966   0.08291192  1.746225  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-t2vq596uksembozbiga81', 'object': 'chat.completion', 'created': 1741258348, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 236, 'completion_tokens': 0, 'total_tokens': 236}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.036 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.385 # Min=-Inf and Max=Inf
#         Pole Angle: 0.118 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.064 # Min=-Inf and Max=Inf
#
#     Observation: [-0.0358252  -1.3854575   0.11783642  2.0635047 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-4ps92g050iwpdtsrz8xgj9', 'object': 'chat.completion', 'created': 1741258382, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 236, 'completion_tokens': 0, 'total_tokens': 236}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.064 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.582 # Min=-Inf and Max=Inf
#         Pole Angle: 0.159 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.390 # Min=-Inf and Max=Inf
#
#     Observation: [-0.06353435 -1.581567    0.15910651  2.390193  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-5mnfd8zhbdpvgu3r1ud7yn', 'object': 'chat.completion', 'created': 1741258413, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 235, 'completion_tokens': 0, 'total_tokens': 235}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.095 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.778 # Min=-Inf and Max=Inf
#         Pole Angle: 0.207 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.727 # Min=-Inf and Max=Inf
#
#     Observation: [-0.09516569 -1.7776892   0.20691037  2.7272406 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-jbc2ousegbzrrwb4q5xu', 'object': 'chat.completion', 'created': 1741258447, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': ''}}], 'usage': {'prompt_tokens': 236, 'completion_tokens': 0, 'total_tokens': 236}, 'system_fingerprint': 'vicuna-13b-v1.5'}
# Raw LLM Response:
# Error processing LLM response: list index out of range
# Total reward: 10.0

# %% [markdown]
# #### LLM-Agent Qwen2.5 7b Coder instruct

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "Qwen2.5-Coder-7B-Instruct-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.033 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.023 # Min=-Inf and Max=Inf
#         Pole Angle: 0.026 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.017 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03283882  0.02259768  0.02591376 -0.01703708]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-rmb9sz12hmb9eaka0eg4aw', 'object': 'chat.completion', 'created': 1741258909, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.033 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.217 # Min=-Inf and Max=Inf
#         Pole Angle: 0.026 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.301 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03329078  0.21733859  0.02557302 -0.30143258]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-vdf7dmvgdlm2b6eaku6vtl', 'object': 'chat.completion', 'created': 1741258914, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.038 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.022 # Min=-Inf and Max=Inf
#         Pole Angle: 0.020 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.001 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03763755  0.02186166  0.01954436 -0.00079543]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-eoy9iilo68mgjp13kpyeps', 'object': 'chat.completion', 'created': 1741258917, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.038 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.174 # Min=-Inf and Max=Inf
#         Pole Angle: 0.020 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.298 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03807478 -0.17353505  0.01952846  0.29798934]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-shm2v4xtszn0pn8fjxrhjq', 'object': 'chat.completion', 'created': 1741258921, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.035 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.369 # Min=-Inf and Max=Inf
#         Pole Angle: 0.025 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.597 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03460408 -0.36892986  0.02548824  0.59676665]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-v25r2722rj9n6utk3vhvp', 'object': 'chat.completion', 'created': 1741258924, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.027 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.564 # Min=-Inf and Max=Inf
#         Pole Angle: 0.037 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.897 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.02722548 -0.56439906  0.03742358  0.89736795]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-gdqbt7t91kvntzoo4j6hef', 'object': 'chat.completion', 'created': 1741258927, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.016 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.370 # Min=-Inf and Max=Inf
#         Pole Angle: 0.055 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.617 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.0159375  -0.36980385  0.05537093  0.6166795 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-324mj946z4stiqdiffkdns', 'object': 'chat.completion', 'created': 1741258931, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 1, 'total_tokens': 216}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.009 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.175 # Min=-Inf and Max=Inf
#         Pole Angle: 0.068 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.342 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00854143 -0.17549737  0.06770453  0.3419372 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-54j8iin7gghzyuoqawbgpi', 'object': 'chat.completion', 'created': 1741258934, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 1, 'total_tokens': 216}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.005 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.019 # Min=-Inf and Max=Inf
#         Pole Angle: 0.075 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.071 # Min=-Inf and Max=Inf
#
#     Observation: [0.00503148 0.01859928 0.07454327 0.0713492 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-x95mylze7sy7ko7at91ys', 'object': 'chat.completion', 'created': 1741258937, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 212, 'completion_tokens': 1, 'total_tokens': 213}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.005 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.178 # Min=-Inf and Max=Inf
#         Pole Angle: 0.076 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.387 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00540346 -0.17750782  0.07597025  0.38658836]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-a88g4l5qb6c43id5ek3ytb', 'object': 'chat.completion', 'created': 1741258941, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.002 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.374 # Min=-Inf and Max=Inf
#         Pole Angle: 0.084 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.702 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00185331 -0.37362137  0.08370202  0.702224  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-a2y2qrkq7ta4lizngke63q', 'object': 'chat.completion', 'created': 1741258944, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 1, 'total_tokens': 216}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.006 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.570 # Min=-Inf and Max=Inf
#         Pole Angle: 0.098 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.020 # Min=-Inf and Max=Inf
#
#     Observation: [-0.00561912 -0.5697976   0.0977465   1.0200378 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-2z1fjvqkrcyam9igqncmrb', 'object': 'chat.completion', 'created': 1741258948, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 212, 'completion_tokens': 1, 'total_tokens': 213}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.017 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.766 # Min=-Inf and Max=Inf
#         Pole Angle: 0.118 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.342 # Min=-Inf and Max=Inf
#
#     Observation: [-0.01701507 -0.7660766   0.11814725  1.3417426 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-s9033jvl64f3pgv7pxnhe', 'object': 'chat.completion', 'created': 1741258951, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.032 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.573 # Min=-Inf and Max=Inf
#         Pole Angle: 0.145 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.088 # Min=-Inf and Max=Inf
#
#     Observation: [-0.0323366  -0.572623    0.14498211  1.0882397 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-joo1qzvkwdfw21b6dikejq', 'object': 'chat.completion', 'created': 1741258954, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 212, 'completion_tokens': 1, 'total_tokens': 213}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.044 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.769 # Min=-Inf and Max=Inf
#         Pole Angle: 0.167 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.423 # Min=-Inf and Max=Inf
#
#     Observation: [-0.04378906 -0.7693278   0.1667469   1.4226769 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-gigr647y2qobp62vk9ebc', 'object': 'chat.completion', 'created': 1741258958, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 212, 'completion_tokens': 1, 'total_tokens': 213}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.059 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.966 # Min=-Inf and Max=Inf
#         Pole Angle: 0.195 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.762 # Min=-Inf and Max=Inf
#
#     Observation: [-0.05917562 -0.9660728   0.19520044  1.7624978 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-tyo7jamgni9d5l3hdei7dv', 'object': 'chat.completion', 'created': 1741258961, 'model': 'qwen2.5-coder-7b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-coder-7b-instruct'}
# Raw LLM Response: 0
# Final Action: 0
# Total reward: 16.0

# %% [markdown]
# #### LLM Agent Mistral AI 7b Instruct

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "Mistral-7B-Instruct-v0.2-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.021 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.005 # Min=-Inf and Max=Inf
#         Pole Angle: -0.034 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.022 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02088822  0.0048689  -0.03419824  0.02169391]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-01uitcahk53bmgaw19sy7wq', 'object': 'chat.completion', 'created': 1741367672, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state and observation, I'}}], 'usage': {'prompt_tokens': 218, 'completion_tokens': 9, 'total_tokens': 227}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state and observation, I
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.021 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.190 # Min=-Inf and Max=Inf
#         Pole Angle: -0.034 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.303 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02079084 -0.18974635 -0.03376435  0.30339378]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-racqt3ewrgrroov0dtz01', 'object': 'chat.completion', 'created': 1741367697, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state and observation, it'}}], 'usage': {'prompt_tokens': 218, 'completion_tokens': 9, 'total_tokens': 227}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state and observation, it
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.025 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.384 # Min=-Inf and Max=Inf
#         Pole Angle: -0.028 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.585 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02458577 -0.38437125 -0.02769648  0.5852399 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-lzizx3jcf2dt4ahypkn0a', 'object': 'chat.completion', 'created': 1741367716, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state and observation, it'}}], 'usage': {'prompt_tokens': 217, 'completion_tokens': 9, 'total_tokens': 226}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state and observation, it
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.032 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.579 # Min=-Inf and Max=Inf
#         Pole Angle: -0.016 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.869 # Min=-Inf and Max=Inf
#
#     Observation: [-0.03227319 -0.5790945  -0.01599168  0.86907107]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-yii20aw7kdigbjnt6e0wjd', 'object': 'chat.completion', 'created': 1741367735, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state, I would recommend'}}], 'usage': {'prompt_tokens': 218, 'completion_tokens': 9, 'total_tokens': 227}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state, I would recommend
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.044 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.774 # Min=-Inf and Max=Inf
#         Pole Angle: 0.001 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.157 # Min=-Inf and Max=Inf
#
#     Observation: [-0.04385508 -0.7739953   0.00138974  1.1566834 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-6r5frc63pjrnytq7bbpxhh', 'object': 'chat.completion', 'created': 1741367757, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state of the cart and'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state of the cart and
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.059 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.969 # Min=-Inf and Max=Inf
#         Pole Angle: 0.025 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.450 # Min=-Inf and Max=Inf
#
#     Observation: [-0.05933499 -0.96913534  0.02452341  1.4498018 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-h12eij5cxp7kq949pk6d07', 'object': 'chat.completion', 'created': 1741367777, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state, it looks like'}}], 'usage': {'prompt_tokens': 217, 'completion_tokens': 9, 'total_tokens': 226}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state, it looks like
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.079 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.165 # Min=-Inf and Max=Inf
#         Pole Angle: 0.054 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.750 # Min=-Inf and Max=Inf
#
#     Observation: [-0.07871769 -1.16455     0.05351944  1.7500448 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-by8n1jld7yqsf0qsefejd', 'object': 'chat.completion', 'created': 1741367799, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state of the cartp'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 9, 'total_tokens': 223}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state of the cartp
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.102 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.360 # Min=-Inf and Max=Inf
#         Pole Angle: 0.089 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.059 # Min=-Inf and Max=Inf
#
#     Observation: [-0.10200869 -1.3602372   0.08852034  2.0588825 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-h7rgs6gj9nq106f0g7hl4zg', 'object': 'chat.completion', 'created': 1741367818, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state of the CartP'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state of the CartP
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.129 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.556 # Min=-Inf and Max=Inf
#         Pole Angle: 0.130 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.378 # Min=-Inf and Max=Inf
#
#     Observation: [-0.12921344 -1.5561444   0.129698    2.3775837 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-r7aalhvzper5nhs1ejo6i5', 'object': 'chat.completion', 'created': 1741367839, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state of the CartP'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 9, 'total_tokens': 223}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state of the CartP
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.160 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.752 # Min=-Inf and Max=Inf
#         Pole Angle: 0.177 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.707 # Min=-Inf and Max=Inf
#
#     Observation: [-0.16033633 -1.7521524   0.17724967  2.707151  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-gyk1dqxmw96br49abca8tw', 'object': 'chat.completion', 'created': 1741367860, 'model': 'mistral-7b-instruct-v0.2', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': ' Based on the current state of the CartP'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'mistral-7b-instruct-v0.2'}
# Raw LLM Response: Based on the current state of the CartP
# Final Action: 0
# Total reward: 10.0

# %% [markdown]
# #### Qwen2.5-14B-DeepSeek-R1-1M

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "Qwen2.5-14B-DeepSeek-R1-1M"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.047 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.016 # Min=-Inf and Max=Inf
#         Pole Angle: 0.038 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.020 # Min=-Inf and Max=Inf
#
#     Observation: [-0.04731366 -0.01620284  0.03819104 -0.01988509]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-zt786u9j8wz7ikkeyc6h', 'object': 'chat.completion', 'created': 1741549402, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, I'm trying to figure out whether"}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, I'm trying to figure out whether
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.048 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.212 # Min=-Inf and Max=Inf
#         Pole Angle: 0.038 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.285 # Min=-Inf and Max=Inf
#
#     Observation: [-0.04763772 -0.21185109  0.03779333  0.2845987 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-5tl36y9ukymdetlnxgwbqp', 'object': 'chat.completion', 'created': 1741549409, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': 'Alright, let me try to figure out whether'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, let me try to figure out whether
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.052 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.407 # Min=-Inf and Max=Inf
#         Pole Angle: 0.043 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.589 # Min=-Inf and Max=Inf
#
#     Observation: [-0.05187474 -0.40749112  0.04348531  0.5889578 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-gu0o1aatp0vunjrodzackj', 'object': 'chat.completion', 'created': 1741549416, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, so I'm trying to figure out"}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 9, 'total_tokens': 225}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, so I'm trying to figure out
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.060 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.603 # Min=-Inf and Max=Inf
#         Pole Angle: 0.055 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.895 # Min=-Inf and Max=Inf
#
#     Observation: [-0.06002456 -0.6031942   0.05526447  0.8950155 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-ctm8cn5w6h4fs7bjr7jwut', 'object': 'chat.completion', 'created': 1741549423, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, let's break this down step by"}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 9, 'total_tokens': 224}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, let's break this down step by
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.072 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.799 # Min=-Inf and Max=Inf
#         Pole Angle: 0.073 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.205 # Min=-Inf and Max=Inf
#
#     Observation: [-0.07208844 -0.7990202   0.07316478  1.2045456 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-vvd137hocuflbh9umv7o7l', 'object': 'chat.completion', 'created': 1741549430, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, so I'm trying to figure out"}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 9, 'total_tokens': 224}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, so I'm trying to figure out
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.088 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.995 # Min=-Inf and Max=Inf
#         Pole Angle: 0.097 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.519 # Min=-Inf and Max=Inf
#
#     Observation: [-0.08806884 -0.9950076   0.09725568  1.5192314 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-tj38vlo52hkiaikxb3g6fi', 'object': 'chat.completion', 'created': 1741549436, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, let's break down the current state"}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 9, 'total_tokens': 224}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, let's break down the current state
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.108 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.191 # Min=-Inf and Max=Inf
#         Pole Angle: 0.128 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 1.841 # Min=-Inf and Max=Inf
#
#     Observation: [-0.107969   -1.1911615   0.12764032  1.84062   ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-kpe33yvtzxch16tl4orkp', 'object': 'chat.completion', 'created': 1741549444, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, so I'm trying to figure out"}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 9, 'total_tokens': 222}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, so I'm trying to figure out
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.132 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.387 # Min=-Inf and Max=Inf
#         Pole Angle: 0.164 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.170 # Min=-Inf and Max=Inf
#
#     Observation: [-0.13179223 -1.3874408   0.16445272  2.1700683 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-1kuxv3a72xf8dsumsdq3e5', 'object': 'chat.completion', 'created': 1741549450, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, let's break down the current state"}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 9, 'total_tokens': 224}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, let's break down the current state
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.160 # Min=-4.8 and Max=4.8
#         Cart Velocity: -1.584 # Min=-Inf and Max=Inf
#         Pole Angle: 0.208 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 2.509 # Min=-Inf and Max=Inf
#
#     Observation: [-0.15954104 -1.5837418   0.20785408  2.5086787 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-xlx55d6qcssvkze039ylgb', 'object': 'chat.completion', 'created': 1741549457, 'model': 'qwen2.5-14b-deepseek-r1-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'length', 'message': {'role': 'assistant', 'content': "Alright, I'm trying to figure out whether"}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 9, 'total_tokens': 224}, 'system_fingerprint': 'qwen2.5-14b-deepseek-r1-1m'}
# Raw LLM Response: Alright, I'm trying to figure out whether
# Final Action: 0
# Total reward: 9.0

# %% [markdown]
# #### Qwen2.5 7b Instruct

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "Qwen2.5-7B-Instruct-1M-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.028 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.014 # Min=-Inf and Max=Inf
#         Pole Angle: 0.035 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: 0.023 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02828094  0.01398263  0.03481926  0.02295804]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-7hoptx03ue3u4jw4io1ymn', 'object': 'chat.completion', 'created': 1741688516, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 216, 'completion_tokens': 1, 'total_tokens': 217}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.028 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.209 # Min=-Inf and Max=Inf
#         Pole Angle: 0.035 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.259 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02800129  0.20858838  0.03527842 -0.25853887]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-xyz6vizsjgegpll8ltji7c', 'object': 'chat.completion', 'created': 1741688519, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 1, 'total_tokens': 216}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.024 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.403 # Min=-Inf and Max=Inf
#         Pole Angle: 0.030 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.540 # Min=-Inf and Max=Inf
#
#     Observation: [-0.02382952  0.4031894   0.03010764 -0.53988904]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-grt9sqku6ra1w38jelgv06', 'object': 'chat.completion', 'created': 1741688522, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.016 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.598 # Min=-Inf and Max=Inf
#         Pole Angle: 0.019 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.823 # Min=-Inf and Max=Inf
#
#     Observation: [-0.01576573  0.5978755   0.01930986 -0.8229355 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-89fdlwlnoc4sm5w0lvkdu', 'object': 'chat.completion', 'created': 1741688525, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.004 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.402 # Min=-Inf and Max=Inf
#         Pole Angle: 0.003 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.524 # Min=-Inf and Max=Inf
#
#     Observation: [-0.00380822  0.40249476  0.00285115 -0.5242423 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-jfdm7434gc6tcpq7o2iqo', 'object': 'chat.completion', 'created': 1741688528, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.004 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.598 # Min=-Inf and Max=Inf
#         Pole Angle: -0.008 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.816 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00424167  0.59757644 -0.00763369 -0.81602544]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-wvng8px0epeverwahdpa7b', 'object': 'chat.completion', 'created': 1741688531, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 215, 'completion_tokens': 1, 'total_tokens': 216}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.016 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.793 # Min=-Inf and Max=Inf
#         Pole Angle: -0.024 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.111 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.0161932  0.7928021 -0.0239542 -1.1110996]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-eiariu00fnincwe2w0jo', 'object': 'chat.completion', 'created': 1741688534, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '0'}}], 'usage': {'prompt_tokens': 211, 'completion_tokens': 1, 'total_tokens': 212}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 0
# Final Action: 0
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.032 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.598 # Min=-Inf and Max=Inf
#         Pole Angle: -0.046 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.826 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.03204924  0.59800285 -0.0461762  -0.8260265 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-acj2vc9ti8cxq799d6ueaf', 'object': 'chat.completion', 'created': 1741688537, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.044 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.794 # Min=-Inf and Max=Inf
#         Pole Angle: -0.063 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.133 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.0440093   0.7937249  -0.06269673 -1.1328676 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-8j9o2b8ztkjhc417mdcs8', 'object': 'chat.completion', 'created': 1741688540, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.060 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.990 # Min=-Inf and Max=Inf
#         Pole Angle: -0.085 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.445 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.0598838   0.98960894 -0.08535407 -1.444537  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-le37wbc0jv0p22ufae4le8', 'object': 'chat.completion', 'created': 1741688543, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.080 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.186 # Min=-Inf and Max=Inf
#         Pole Angle: -0.114 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.763 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.07967597  1.1856712  -0.11424482 -1.7626235 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-0vz2gi1r6je9ihwbgng4nvm', 'object': 'chat.completion', 'created': 1741688545, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.103 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.382 # Min=-Inf and Max=Inf
#         Pole Angle: -0.149 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -2.089 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.1033894   1.3818853  -0.14949729 -2.088541  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-gcb9qqtzqyd1fn2a6dnvjp', 'object': 'chat.completion', 'created': 1741688548, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.131 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.578 # Min=-Inf and Max=Inf
#         Pole Angle: -0.191 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -2.423 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.1310271  1.578167  -0.1912681 -2.4234684]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-k1q65n67zrjva4c5im0sh9', 'object': 'chat.completion', 'created': 1741688551, 'model': 'qwen2.5-7b-instruct-1m', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 211, 'completion_tokens': 1, 'total_tokens': 212}, 'system_fingerprint': 'qwen2.5-7b-instruct-1m'}
# Raw LLM Response: 1
# Final Action: 1
# Total reward: 13.0

# %% [markdown]
# #### Qwen2.5-1.5B-Instruct-GGUF

# %%
# LLM API details (Modify if needed)
LLM_API_URL = "http://localhost:1234/v1/chat/completions"  # Change to your LM Studio API URL
MODEL_NAME = "Qwen2.5-1.5B-Instruct-GGUF"  # Adjust if needed

# %%
def query_llm(observation):
    """Sends observation to the LLM and retrieves an action (0 or 1)."""
    prompt = f"""
    Your task is to control a cart in CartPole-v1 to keep the pole balanced.

        Current State:
        Cart Position: {observation[0]:.3f} # Min=-4.8 and Max=4.8
        Cart Velocity: {observation[1]:.3f} # Min=-Inf and Max=Inf
        Pole Angle: {observation[2]:.3f} # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
        Pole Angular Velocity: {observation[3]:.3f} # Min=-Inf and Max=Inf
    
    Observation: {observation}
    
    Respond with ONLY '0' or '1' and nothing else.
    """

    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "system", "content": "You are a reinforcement learning agent for CartPole."},
                     {"role": "user", "content": prompt}],
        "temperature": 0.5,
        "max_tokens": 10,
        "stop": ["\n"],
    }

    try:
        print(prompt)  # Debugging 
        response = requests.post(LLM_API_URL, headers={"Content-Type": "application/json"}, data=json.dumps(payload))
        response_json = response.json()
        print("LLM Response:", response_json)

        # Extract raw response
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        print(f"Raw LLM Response: {raw_result}")

        # Extract the first valid action (0 or 1)
        #action = int(raw_result[0]) if raw_result and raw_result[0] in ["0", "1"] else 0
        raw_result = response_json.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
        raw_result = raw_result.split()[0]  # Ensure we take the first valid word
        action = 1 if raw_result == "1" else 0  # Force a binary output
        
        print(f"Final Action: {action}")
        return action  # ✅ Ensure the function returns an action

    except Exception as e:
        print("Error processing LLM response:", e)
        return 0  # Default action in case of failure

# %%
def run_cartpole():
    """Runs the CartPole-v1 environment with the LLM-based agent."""
    env = gym.make("CartPole-v1", render_mode="human")  # Change render_mode to 'None' if no visualization needed
    observation, info = env.reset()
    
    total_reward = 0
    for step in range(200):  # Maximum steps per episode
        action = query_llm(observation)
        observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()
        if terminated or truncated:
            break  # End episode if the pole falls or max steps reached

        time.sleep(0.05)  # Small delay for better visualization

    env.close()
    print(f"Total reward: {total_reward}")

# %%
if __name__ == "__main__":
    run_cartpole()
# Out:
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.007 # Min=-4.8 and Max=4.8
#         Cart Velocity: -0.040 # Min=-Inf and Max=Inf
#         Pole Angle: -0.045 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.022 # Min=-Inf and Max=Inf
#
#     Observation: [-0.00696013 -0.04000566 -0.04463327 -0.02249608]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-9a8zpsydp5uqe6sxzywsoi', 'object': 'chat.completion', 'created': 1741722420, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.008 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.156 # Min=-Inf and Max=Inf
#         Pole Angle: -0.045 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.329 # Min=-Inf and Max=Inf
#
#     Observation: [-0.00776025  0.15572701 -0.04508319 -0.3289205 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-d1hle6jw8nvd8e6pbidfeb', 'object': 'chat.completion', 'created': 1741722423, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: -0.005 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.351 # Min=-Inf and Max=Inf
#         Pole Angle: -0.052 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.635 # Min=-Inf and Max=Inf
#
#     Observation: [-0.00464571  0.3514608  -0.0516616  -0.63547283]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-eopfwq4n0mpu6xiz293n5', 'object': 'chat.completion', 'created': 1741722425, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.002 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.547 # Min=-Inf and Max=Inf
#         Pole Angle: -0.064 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -0.944 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.00238351  0.5472638  -0.06437106 -0.9439672 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-9qyhlnzkybgnxdp5dqy9o', 'object': 'chat.completion', 'created': 1741722428, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.013 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.743 # Min=-Inf and Max=Inf
#         Pole Angle: -0.083 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.256 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.01332879  0.7431911  -0.0832504  -1.2561616 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-7y0y9e7kb2r2qm6nfrhk2b', 'object': 'chat.completion', 'created': 1741722430, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.028 # Min=-4.8 and Max=4.8
#         Cart Velocity: 0.939 # Min=-Inf and Max=Inf
#         Pole Angle: -0.108 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.574 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.02819261  0.93927425 -0.10837363 -1.573715  ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-sosafkz8d3bbc5dbd2csf', 'object': 'chat.completion', 'created': 1741722433, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.047 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.136 # Min=-Inf and Max=Inf
#         Pole Angle: -0.140 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -1.898 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.04697809  1.135509   -0.13984793 -1.8981397 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-502v6d1x4hsbn583p5hnii', 'object': 'chat.completion', 'created': 1741722435, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 213, 'completion_tokens': 1, 'total_tokens': 214}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
#
#     Your task is to control a cart in CartPole-v1 to keep the pole balanced.
#
#         Current State:
#         Cart Position: 0.070 # Min=-4.8 and Max=4.8
#         Cart Velocity: 1.332 # Min=-Inf and Max=Inf
#         Pole Angle: -0.178 # Min=-0.418 (-24 degrees) rad and Max=0.418 rad (24 degrees)
#         Pole Angular Velocity: -2.231 # Min=-Inf and Max=Inf
#
#     Observation: [ 0.06968828  1.3318415  -0.17781073 -2.2307446 ]
#
#     Respond with ONLY '0' or '1' and nothing else.
#
# LLM Response: {'id': 'chatcmpl-jo28l91sy7j5qref11v8y', 'object': 'chat.completion', 'created': 1741722437, 'model': 'qwen2.5-1.5b-instruct', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '1'}}], 'usage': {'prompt_tokens': 214, 'completion_tokens': 1, 'total_tokens': 215}, 'system_fingerprint': 'qwen2.5-1.5b-instruct'}
# Raw LLM Response: 1
# Final Action: 1
# Total reward: 8.0
